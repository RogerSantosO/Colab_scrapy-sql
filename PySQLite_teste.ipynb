# %%
# !pip install scrapy
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scrapy in /usr/local/lib/python3.7/dist-packages (2.6.3)
# Requirement already satisfied: protego>=0.1.15 in /usr/local/lib/python3.7/dist-packages (from scrapy) (0.2.1)
# Requirement already satisfied: parsel>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from scrapy) (1.6.0)
# Requirement already satisfied: cssselect>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from scrapy) (1.1.0)
# Requirement already satisfied: service-identity>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from scrapy) (21.1.0)
# Requirement already satisfied: zope.interface>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from scrapy) (5.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from scrapy) (57.4.0)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /usr/local/lib/python3.7/dist-packages (from scrapy) (2.0.6)
# Requirement already satisfied: lxml>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from scrapy) (4.9.1)
# Requirement already satisfied: itemadapter>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from scrapy) (0.7.0)
# Requirement already satisfied: cryptography>=3.3 in /usr/local/lib/python3.7/dist-packages (from scrapy) (38.0.1)
# Requirement already satisfied: tldextract in /usr/local/lib/python3.7/dist-packages (from scrapy) (3.3.1)
# Requirement already satisfied: w3lib>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from scrapy) (2.0.1)
# Requirement already satisfied: Twisted>=18.9.0 in /usr/local/lib/python3.7/dist-packages (from scrapy) (22.8.0)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from scrapy) (22.1.0)
# Requirement already satisfied: queuelib>=1.4.2 in /usr/local/lib/python3.7/dist-packages (from scrapy) (1.6.2)
# Requirement already satisfied: itemloaders>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from scrapy) (1.0.6)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=3.3->scrapy) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=3.3->scrapy) (2.21)
# Requirement already satisfied: jmespath>=0.9.5 in /usr/local/lib/python3.7/dist-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: six>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from parsel>=1.5.0->scrapy) (1.15.0)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.7/dist-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.7/dist-packages (from service-identity>=18.1.0->scrapy) (22.1.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.7/dist-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: hyperlink>=17.1.1 in /usr/local/lib/python3.7/dist-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: constantly>=15.1 in /usr/local/lib/python3.7/dist-packages (from Twisted>=18.9.0->scrapy) (15.1.0)
# Requirement already satisfied: Automat>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from Twisted>=18.9.0->scrapy) (20.2.0)
# Requirement already satisfied: incremental>=21.3.0 in /usr/local/lib/python3.7/dist-packages (from Twisted>=18.9.0->scrapy) (21.3.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from Twisted>=18.9.0->scrapy) (4.1.1)
# Requirement already satisfied: idna>=2.5 in /usr/local/lib/python3.7/dist-packages (from hyperlink>=17.1.1->Twisted>=18.9.0->scrapy) (2.10)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tldextract->scrapy) (2.23.0)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from tldextract->scrapy) (3.8.0)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.7/dist-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2022.6.15)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd

# %%
# !python3 /content/drive/MyDrive/cripto_scrapy/extract.py
# !python3 /content/drive/MyDrive/cripto_scrapy/transform.py
# Out:
# 2022-10-04 19:11:15 [scrapy.utils.log] INFO: Scrapy 2.6.3 started (bot: scrapybot)
# 2022-10-04 19:11:15 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.7.14 (default, Sep  8 2022, 00:06:44) - [GCC 7.5.0], pyOpenSSL 22.1.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# 2022-10-04 19:11:15 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/104.0.0.0 Safari/537.36'}
# 2022-10-04 19:11:15 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-10-04 19:11:15 [scrapy.extensions.telnet] INFO: Telnet Password: c870727eafe5e24d
# 2022-10-04 19:11:15 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-10-04 19:11:15 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-10-04 19:11:15 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-10-04 19:11:15 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-10-04 19:11:15 [scrapy.core.engine] INFO: Spider opened
# 2022-10-04 19:11:15 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-10-04 19:11:15 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/terra-luna/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/bitcoin/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/terra-luna-v2/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/polygon/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/avalanche/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/bnb/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/flow/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/solana/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/ethereum/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/cardano/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/dogecoin/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/ethereum-classic/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/ethereum/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://coinmarketcap.com/currencies/litecoin/> (referer: None)
# 2022-10-04 19:11:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/terra-luna/>
# {'cripto': 'Terra Classic', 'valor': '0.0003083'}
# 2022-10-04 19:11:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/bitcoin/>
# {'cripto': 'Bitcoin', 'valor': '20123.28'}
# 2022-10-04 19:11:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/terra-luna-v2/>
# {'cripto': 'Terra', 'valor': '2.51'}
# 2022-10-04 19:11:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/polygon/>
# {'cripto': 'Polygon', 'valor': '0.8365'}
# 2022-10-04 19:11:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/avalanche/>
# {'cripto': 'Avalanche', 'valor': '17.37'}
# 2022-10-04 19:11:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/bnb/>
# {'cripto': 'BNB', 'valor': '296.07'}
# 2022-10-04 19:11:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/flow/>
# {'cripto': 'Flow', 'valor': '1.71'}
# 2022-10-04 19:11:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/solana/>
# {'cripto': 'Solana', 'valor': '34.10'}
# 2022-10-04 19:11:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/ethereum/>
# {'cripto': 'Ethereum', 'valor': '1349.89'}
# 2022-10-04 19:11:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/cardano/>
# {'cripto': 'Cardano', 'valor': '0.4338'}
# 2022-10-04 19:11:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/dogecoin/>
# {'cripto': 'Dogecoin', 'valor': '0.06413'}
# 2022-10-04 19:11:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/ethereum-classic/>
# {'cripto': 'Ethereum Classic', 'valor': '27.70'}
# 2022-10-04 19:11:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/ethereum/>
# {'cripto': 'Ethereum', 'valor': '1349.89'}
# 2022-10-04 19:11:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://coinmarketcap.com/currencies/litecoin/>
# {'cripto': 'Litecoin', 'valor': '54.80'}
# 2022-10-04 19:11:16 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-10-04 19:11:16 [scrapy.extensions.feedexport] INFO: Stored csv feed (14 items) in: cripto.csv
# 2022-10-04 19:11:16 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 4258,
#  'downloader/request_count': 14,
#  'downloader/request_method_count/GET': 14,
#  'downloader/response_bytes': 841757,
#  'downloader/response_count': 14,
#  'downloader/response_status_count/200': 14,
#  'elapsed_time_seconds': 0.376875,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 10, 4, 19, 11, 16, 105472),
#  'httpcompression/response_bytes': 4651794,
#  'httpcompression/response_count': 14,
#  'item_scraped_count': 14,
#  'log_count/DEBUG': 29,
#  'log_count/INFO': 11,
#  'memusage/max': 97087488,
#  'memusage/startup': 97087488,
#  'response_received_count': 14,
#  'scheduler/dequeued': 14,
#  'scheduler/dequeued/memory': 14,
#  'scheduler/enqueued': 14,
#  'scheduler/enqueued/memory': 14,
#  'start_time': datetime.datetime(2022, 10, 4, 19, 11, 15, 728597)}
# 2022-10-04 19:11:16 [scrapy.core.engine] INFO: Spider closed (finished)
# | cripto   |   busd |   valor_de_compra |   valor_atual |   liquido |   porcentagem |
# |:---------|-------:|------------------:|--------------:|----------:|--------------:|
# | AVAX     |  35.14 |             20.31 |         17.37 |     -5.09 |        -14.48 |
# | BNB      |  49.83 |            291.4  |        296.07 |      0.8  |          1.6  |
# | BTC      | 144.64 |          21271.3  |      20123.3  |     -7.81 |         -5.4  |
# | ADA      |  49.96 |              0.49 |          0.43 |     -6.02 |        -12.04 |
# | DOGE     |  49.97 |              0.06 |          0.06 |      0.63 |          1.26 |
# | ETH      |  19.12 |           1707.36 |       1349.89 |     -4    |        -20.94 |
# | ETH      | 101.37 |           1759.92 |       1349.89 |    -23.62 |        -23.3  |
# | ETC      |  12.78 |             38.73 |         27.7  |     -3.64 |        -28.48 |
# | FLOW     |  29.98 |              1.84 |          1.71 |     -2.18 |         -7.27 |
# | LTC      |  19.98 |             60.37 |         54.8  |     -1.84 |         -9.23 |
# | MATIC    |  91.6  |              0.89 |          0.84 |     -5.19 |         -5.66 |
# | SOL      |  38.56 |             34.74 |         34.1  |     -0.71 |         -1.84 |

# %%
import sqlite3

# %%
conn = sqlite3.connect('cyptable.db')
print("Opened database successfully");

conn.execute('''
CREATE TABLE IF NOT EXISTS Criptos(cripto text, 
                      busd integer,
                      quantidade integer, 
                      valor_de_compra integer, 
                      valor_atual integer,
liquido integer,
porcentagem integer);''')

conn.commit()

print("Table created successfully");

conn.close()
# Out:
# Opened database successfully
# Table created successfully

# %%
conn = sqlite3.connect('cyptable.db')


df = pd.read_csv('resultado.csv')
for index,row in df.iterrows():
  params = row.cripto,row.busd,row.quantidade,row.valor_de_compra,row.valor_atual,row.liquido,row.porcentagem
  conn.execute("INSERT INTO Criptos VALUES (? ,? , ?, ?, ?, ?, ?)",params)

conn.commit()


conn.close()

# %%
conn = sqlite3.connect('cyptable.db')


db = conn.execute('''
SELECT * FROM Criptos''')

for row in db:
  print(row)

conn.commit()


conn.close()
# Out:
# ('AVAX', 35.14, 1.73, 20.31, 17.37, -5.09, -14.48)
# ('BNB', 49.83, 0.17, 291.4, 296.07, 0.8, 1.6)
# ('BTC', 144.64, 0.01, 21271.32, 20123.28, -7.81, -5.4)
# ('ADA', 49.96, 101.3, 0.49, 0.43, -6.02, -12.04)
# ('DOGE', 49.97, 789, 0.06, 0.06, 0.63, 1.26)
# ('ETH', 19.12, 0.01, 1707.36, 1349.89, -4, -20.94)
# ('ETH', 101.37, 0.06, 1759.92, 1349.89, -23.62, -23.3)
# ('ETC', 12.78, 0.33, 38.73, 27.7, -3.64, -28.48)
# ('FLOW', 29.98, 16.26, 1.84, 1.71, -2.18, -7.27)
# ('LTC', 19.98, 0.33, 60.37, 54.8, -1.84, -9.23)
# ('MATIC', 91.6, 103.3, 0.89, 0.84, -5.19, -5.66)
# ('SOL', 38.56, 1.11, 34.74, 34.1, -0.71, -1.84)

# %%
display(df)
# Out:
#    cripto    busd  quantidade  valor_de_compra  valor_atual  liquido  \
# 0    AVAX   35.14        1.73            20.31        17.37    -5.09
# 1     BNB   49.83        0.17           291.40       296.07     0.80
# 2     BTC  144.64        0.01         21271.32     20123.28    -7.81
# 3     ADA   49.96      101.30             0.49         0.43    -6.02
# 4    DOGE   49.97      789.00             0.06         0.06     0.63
# 5     ETH   19.12        0.01          1707.36      1349.89    -4.00
# 6     ETH  101.37        0.06          1759.92      1349.89   -23.62
# 7     ETC   12.78        0.33            38.73        27.70    -3.64
# 8    FLOW   29.98       16.26             1.84         1.71    -2.18
# 9     LTC   19.98        0.33            60.37        54.80    -1.84
# 10  MATIC   91.60      103.30             0.89         0.84    -5.19
# 11    SOL   38.56        1.11            34.74        34.10    -0.71
#
#     porcentagem
# 0        -14.48
# 1          1.60
# 2         -5.40
# 3        -12.04
# 4          1.26
# 5        -20.94
# 6        -23.30
# 7        -28.48
# 8         -7.27
# 9         -9.23
# 10        -5.66
# 11        -1.84
